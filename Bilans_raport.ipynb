# %%
import pandas as pd
import numpy as np

df2=pd.read_excel('/content/drive/MyDrive/maszynoweBilansOnlyV2.xlsx', index_col=False)
df2['wzrost'] = np.where(df2['symbol'].shift(-1) == df2['symbol'], (df2['kapitalizacja'].shift(-1)-df2['kapitalizacja'])/df2['kapitalizacja'].shift(-1), 9999)
df2['wzrost2'] = np.where(df2['wzrost'] > 0.05,1,0)
df2['wzrost3'] = np.where(df2['wzrost'] < -0.10,1,0)
df2['wzrost'] = np.where(df2['wzrost'] > 0.19,1,0)


print(df2.columns)
# Out:
# Index(['Unnamed: 0', 'symbol', 'okres', 'Przychody ze sprzedaży',
#        'Przychody ze sprzedażyproc', 'Przychody ze sprzedażyprocROK',
#        'Przychody ze sprzedażyprocROK2', 'Zysk ze sprzedaży',
#        'Zysk ze sprzedażyproc', 'Zysk ze sprzedażyprocROK',
#        'Zysk ze sprzedażyprocROK2', 'Zysk operacyjny (EBIT)',
#        'Zysk operacyjny (EBIT)proc', 'Zysk operacyjny (EBIT)procROK',
#        'Zysk operacyjny (EBIT)procROK2', 'Zysk z działalności gospodarczej',
#        'Zysk z działalności gospodarczejproc',
#        'Zysk z działalności gospodarczejprocROK',
#        'Zysk z działalności gospodarczejprocROK2', 'Zysk przed opodatkowaniem',
#        'Zysk przed opodatkowaniemproc', 'Zysk przed opodatkowaniemprocROK',
#        'Zysk przed opodatkowaniemprocROK2', 'Zysk netto', 'Zysk nettoproc',
#        'Zysk nettoprocROK', 'Zysk nettoprocROK2',
#        'Zysk netto akcjonariuszy jednostki dominującej',
#        'Zysk netto akcjonariuszy jednostki dominującejproc',
#        'Zysk netto akcjonariuszy jednostki dominującejprocROK',
#        'Zysk netto akcjonariuszy jednostki dominującejprocROK2',
#        'Aktywa trwałe', 'Aktywa trwałeproc', 'Aktywa trwałeprocROK',
#        'Aktywa trwałeprocROK2', 'Aktywa obrotowe', 'Aktywa obrotoweproc',
#        'Aktywa obrotoweprocROK', 'Aktywa obrotoweprocROK2', 'Aktywa razem',
#        'Aktywa razemproc', 'Aktywa razemprocROK', 'Aktywa razemprocROK2',
#        'Kapitał własny akcjonariuszy jednostki dominującej',
#        'Kapitał własny akcjonariuszy jednostki dominującejproc',
#        'Kapitał własny akcjonariuszy jednostki dominującejprocROK',
#        'Kapitał własny akcjonariuszy jednostki dominującejprocROK2',
#        'Zobowiązania długoterminowe', 'Zobowiązania długoterminoweproc',
#        'Zobowiązania długoterminoweprocROK',
#        'Zobowiązania długoterminoweprocROK2', 'Zobowiązania krótkoterminowe',
#        'Zobowiązania krótkoterminoweproc',
#        'Zobowiązania krótkoterminoweprocROK',
#        'Zobowiązania krótkoterminoweprocROK2', 'Pasywa razem',
#        'Pasywa razemproc', 'Pasywa razemprocROK', 'Pasywa razemprocROK2',
#        'Przepływy pieniężne z działalności operacyjnej',
#        'Przepływy pieniężne z działalności operacyjnejproc',
#        'Przepływy pieniężne z działalności operacyjnejprocROK',
#        'Przepływy pieniężne z działalności operacyjnejprocROK2',
#        'Przepływy pieniężne z działalności inwestycyjnej',
#        'Przepływy pieniężne z działalności inwestycyjnejproc',
#        'Przepływy pieniężne z działalności inwestycyjnejprocROK',
#        'Przepływy pieniężne z działalności inwestycyjnejprocROK2',
#        'Przepływy pieniężne z działalności finansowej',
#        'Przepływy pieniężne z działalności finansowejproc',
#        'Przepływy pieniężne z działalności finansowejprocROK',
#        'Przepływy pieniężne z działalności finansowejprocROK2',
#        'Przepływy pieniężne razem', 'Przepływy pieniężne razemproc',
#        'Przepływy pieniężne razemprocROK', 'Przepływy pieniężne razemprocROK2',
#        'Kurs', 'cena akt', 'kapitalizacja', 'wzrost', 'wzrost2', 'wzrost3'],
#       dtype='object')

# %%
df=df2.drop(columns=['okres','symbol','Unnamed: 0','kapitalizacja','wzrost2','wzrost3','Kurs','cena akt'])
for col in df.columns:

  #print(x[col].value_counts())
  df=pd.get_dummies(df, columns=[col],drop_first=True)
print(df.shape)



x= df.drop(columns=['wzrost_1'])
#x=x.loc[~(x==0).all(axis=1)]
#print(x)
# Out:
# (36927, 624)

# %%
y= df['wzrost_1']

# %%
from keras.models import load_model

model = load_model('/content/drive/MyDrive/Bilans_spadek_03_02_2025.keras')

model.summary()

wagilist=model.get_weights()

print(wagilist[0])

# dfWagi=pd.DataFrame(wagilist[0])
# dfWagi.to_excel('/content/drive/MyDrive/wagi.xlsx')

# lll=dfAKT.drop(columns=['wzrost_1'])
# lll=lll.columns
# lll=pd.DataFrame(lll)
# lll.to_excel('/content/drive/MyDrive/kolumny.xlsx')
# print(lll)


prediction = model.predict(df.drop(columns=['wzrost_1']))
#prediction = model.predict(df.drop(columns=['wzrost_1']))
#prediction = model.predict(x_test)

symbolList=df2['symbol'].to_list()
okresList=df2['okres'].to_list()
listaIDX=df2.index.to_list()
listaIDX=df2.index.to_list()
c=0
ilosc_prawd=0
ilosc_prawd_5_proc=0
minus_10_procc=0
www=0
ggg=0

### raport ###

DFraport=pd.DataFrame(df2['symbol'].unique() )
DFraport=DFraport.set_index(0)

for x in prediction:
  symbol=df2.loc[listaIDX[c],'symbol']
  if df2.loc[listaIDX[c],'okres'].find('wrz24') !=-1 or df2.loc[listaIDX[c],'okres'].find('paź24') !=-1:

      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresPoprzedni']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'poprzedniKwartalSpadek_bilans']=  round(x[0],2)
  if df2.loc[listaIDX[c],'okres'].find('gru24') !=-1 or df2.loc[listaIDX[c],'okres'].find('sty25') !=-1:
      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresAktualny']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'AktualnyKwartalSpadek_bilans']=  round(x[0],2)
  if df2.loc[listaIDX[c],'okres'].find('AKT') !=-1:
      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresAktualny_spadek_CENA_Bilans']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'AktualnyKwartal_Spadek_CENA_Bilans']=  round(x[0],2)
      DFraport.loc[symbol,'Kurs']=   df2.loc[listaIDX[c],'Kurs']
      DFraport.loc[symbol,'cena akt']=  df2.loc[listaIDX[c],'cena akt']

      # DFraport.loc[symbol,'średnia ważona']=   df2.loc[listaIDX[c],'średnia ważona']
      # #DFraport.loc[symbol,'STOCH_RSI']=  df2.loc[listaIDX[c],'STOCH_RSI']
      # DFraport.loc[symbol,'CFD']=  df2.loc[listaIDX[c],'CFD']
  #if str(round(x[0],2)) == '0.12':
  if x[0] > 0.3:
    www=www+1
    if str(df2.loc[listaIDX[c],'wzrost']) == '1':
      ilosc_prawd=ilosc_prawd+1
    if str(df2.loc[listaIDX[c],'wzrost2']) == '1':
      ilosc_prawd_5_proc=ilosc_prawd_5_proc+1
    if str(df2.loc[listaIDX[c],'wzrost3']) == '1':
      minus_10_procc=minus_10_procc+1
  if str(df2.loc[listaIDX[c],'wzrost']) == '1':
    ggg=ggg+1
  c=c+1





print(DFraport)
DFraport.to_excel('/content/drive/MyDrive/raportSpadekBilans.xlsx')
print(ilosc_prawd)
print(www)
print('procent + 20%')
print((ilosc_prawd/www)*100)
print('procent + 5%')
print((ilosc_prawd_5_proc/www)*100)
print('procent <> -10%')
print((minus_10_procc/www)*100)
print('procent + 20% w test')
print((ilosc_prawd/ggg)*100)
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_70 (Dense)                     │ (None, 512)                 │         319,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_35 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_71 (Dense)                     │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 960,005 (3.66 MB)
#  Trainable params: 320,001 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 640,004 (2.44 MB)
# [[ 0.01480493 -0.03883854  0.05818373 ...  0.05111525 -0.06069597
#   -0.04743798]
#  [ 0.05951202  0.0696434   0.01220266 ...  0.03942274  0.01125477
#    0.02128901]
#  [ 0.00935122  0.04174573  0.04071109 ... -0.01373495 -0.0092872
#    0.01387919]
#  ...
#  [-0.01852826  0.00047437  0.03205593 ...  0.02459786  0.0218381
#   -0.06419841]
#  [ 0.06048257  0.06931099 -0.0129547  ...  0.07180957  0.04483315
#   -0.0132397 ]
#  [-0.05292203  0.05738589  0.02396519 ... -0.00354372  0.05505791
#    0.00499369]]
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
#     symbol okresAktualny_spadek_CENA_Bilans  \
# 0
# PCO    PCO                              AKT
# GOV    GOV                              AKT
# MGT    MGT                              AKT
# ACG    ACG                              AKT
# ATS    ATS                              AKT
# ..     ...                              ...
# CRM    CRM                              AKT
# CSR    CSR                              AKT
# MOC    MOC                              AKT
# PRI    PRI                              AKT
# ICE    ICE                              AKT
#
#      AktualnyKwartal_Spadek_CENA_Bilans   Kurs  cena akt  okresPoprzedni  \
# 0
# PCO                                0.43  51.00    15.420             NaN
# GOV                                0.26   0.29     0.270             NaN
# MGT                                0.19  79.80    70.000  2024/Q3(wrz24)
# ACG                                0.20  27.50    32.600  2024/Q3(wrz24)
# ATS                                0.34   2.64     0.090             NaN
# ..                                  ...    ...       ...             ...
# CRM                                0.22   0.38     0.516  2024/Q3(wrz24)
# CSR                                0.34   7.90     5.450  2024/Q3(wrz24)
# MOC                                0.21  10.10     9.100  2024/Q3(wrz24)
# PRI                                0.28   3.76     3.800  2024/Q3(wrz24)
# ICE                                0.22   7.80     8.420  2024/Q3(wrz24)
#
#      poprzedniKwartalSpadek_bilans   okresAktualny  \
# 0
# PCO                            NaN             NaN
# GOV                            NaN             NaN
# MGT                           0.20             NaN
# ACG                           0.15             NaN
# ATS                            NaN             NaN
# ..                             ...             ...
# CRM                           0.20  2024/Q4(gru24)
# CSR                           0.25  2024/Q4(gru24)
# MOC                           0.32  2024/Q4(gru24)
# PRI                           0.20  2024/Q4(gru24)
# ICE                           0.27  2024/Q4(gru24)
#
#      AktualnyKwartalSpadek_bilans
# 0
# PCO                           NaN
# GOV                           NaN
# MGT                           NaN
# ACG                           NaN
# ATS                           NaN
# ..                            ...
# CRM                          0.22
# CSR                          0.32
# MOC                          0.16
# PRI                          0.26
# ICE                          0.16
#
# [763 rows x 9 columns]
# 1460
# 7530
# procent + 20%
# 19.389110225763613
# procent + 5%
# 31.79282868525896
# procent <> -10%
# 45.0863213811421
# procent + 20% w test
# 21.518054532056006

# %%
from keras.models import load_model

model = load_model('/content/drive/MyDrive/Bilans_wzrost_03_02_2025.keras')

model.summary()

wagilist=model.get_weights()

print(wagilist[0])

dfWagi=pd.DataFrame(wagilist[0])
dfWagi['srednia']=dfWagi.mean(axis=1)
dfWagi=dfWagi.sort_values(by='srednia',ascending=False)
#dfWagi.to_excel('/content/drive/MyDrive/wagiMAKRO_EKO.xlsx')

lll=df.drop(columns=['wzrost_1'])
lll=lll.columns
lll=pd.DataFrame(lll)
#lll.to_excel('/content/drive/MyDrive/kolumnyMAKRO_EKO.xlsx')
print(lll)

dfWagi['kolumny']=lll
dfWagi=dfWagi[['kolumny','srednia']]
# dfWagi.to_excel('/content/drive/MyDrive/wagiMAKRO_EKO.xlsx')

#

# dfWagi=pd.DataFrame(wagilist[0])
# dfWagi.to_excel('/content/drive/MyDrive/wagi.xlsx')

# lll=dfAKT.drop(columns=['wzrost_1'])
# lll=lll.columns
# lll=pd.DataFrame(lll)
# lll.to_excel('/content/drive/MyDrive/kolumny.xlsx')
# print(lll)

#prediction = model.predict(dfAKT.drop(columns=['wzrost_1']))
prediction = model.predict(df.drop(columns=['wzrost_1']))
#prediction = model.predict(x_test)

symbolList=df2['symbol'].to_list()
okresList=df2['okres'].to_list()
listaIDX=df2.index.to_list()
listaIDX=df2.index.to_list()
c=0
ilosc_prawd=0
ilosc_prawd_5_proc=0
minus_10_procc=0
www=0
ggg=0

### raport ###


for x in prediction:
  symbol=df2.loc[listaIDX[c],'symbol']
  if df2.loc[listaIDX[c],'okres'].find('wrz24') !=-1 or df2.loc[listaIDX[c],'okres'].find('paź24') !=-1:

      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresPoprzedniBilans']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'poprzedniKwartalWzrostBilans']=  round(x[0],2)
  if df2.loc[listaIDX[c],'okres'].find('gru24') !=-1 or df2.loc[listaIDX[c],'okres'].find('sty25') !=-1:
      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresAktualnyBilans']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'AktualnyKwartalWzrostBilans']=  round(x[0],2)

  if df2.loc[listaIDX[c],'okres'].find('AKT') !=-1:
      DFraport.loc[symbol,'symbol']=df2.loc[listaIDX[c],'symbol']
      DFraport.loc[symbol,'okresAktualnyCENA_Bilans']= df2.loc[listaIDX[c],'okres']
      DFraport.loc[symbol,'AktualnyKwartalWzrostCENA_Bilans']=  round(x[0],2)
  #if str(round(x[0],2)) == '0.12':
  if x[0] > 0.4:
    if df2.loc[listaIDX[c],'okres'].find('wrz24') !=-1 or df2.loc[listaIDX[c],'okres'].find('paź24') !=-1:
      print(df2.loc[listaIDX[c],'symbol'])
      print(df2.loc[listaIDX[c],'okres'])
      print(round(x[0],2))
    www=www+1
    if str(df2.loc[listaIDX[c],'wzrost']) == '1':
      ilosc_prawd=ilosc_prawd+1
    if str(df2.loc[listaIDX[c],'wzrost2']) == '1':
      ilosc_prawd_5_proc=ilosc_prawd_5_proc+1
    if str(df2.loc[listaIDX[c],'wzrost3']) == '1':
      minus_10_procc=minus_10_procc+1
  if str(df2.loc[listaIDX[c],'wzrost']) == '1':
    ggg=ggg+1
  c=c+1





print(DFraport)
DFraport.to_excel('/content/drive/MyDrive/raportSpadekBilans.xlsx')
print(ilosc_prawd)
print(www)
print('procent + 20%')
print((ilosc_prawd/www)*100)
print('procent + 5%')
print((ilosc_prawd_5_proc/www)*100)
print('procent <> -10%')
print((minus_10_procc/www)*100)
print('procent + 20% w test')
print((ilosc_prawd/ggg)*100)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 512)                 │         319,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 960,005 (3.66 MB)
#  Trainable params: 320,001 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 640,004 (2.44 MB)
# [[-0.05227135  0.04367377 -0.05527747 ...  0.04531028  0.02273377
#    0.06209316]
#  [-0.10225227  0.03089385 -0.04524172 ... -0.00495849  0.04533021
#    0.10120776]
#  [-0.05392897  0.01373577  0.09418331 ... -0.02441006 -0.00257395
#    0.01956312]
#  ...
#  [ 0.00135882  0.04011583 -0.01847572 ...  0.04647072 -0.00298408
#    0.01086046]
#  [-0.06546319  0.05184237  0.06588943 ... -0.03298325 -0.02463048
#   -0.02442723]
#  [ 0.06253731  0.03313492  0.08498851 ...  0.07266629  0.01774979
#    0.01483154]]
#                                                     0
# 0            Przychody ze sprzedaży_(0.00517, 0.0371]
# 1             Przychody ze sprzedaży_(0.0371, 0.0877]
# 2              Przychody ze sprzedaży_(0.0877, 0.154]
# 3               Przychody ze sprzedaży_(0.154, 0.238]
# 4               Przychody ze sprzedaży_(0.238, 0.347]
# ..                                                ...
# 618  Przepływy pieniężne razemprocROK2_(0.696, 0.987]
# 619  Przepływy pieniężne razemprocROK2_(0.987, 1.175]
# 620  Przepływy pieniężne razemprocROK2_(1.175, 1.819]
# 621  Przepływy pieniężne razemprocROK2_(1.819, 4.464]
# 622    Przepływy pieniężne razemprocROK2_(4.464, inf]
#
# [623 rows x 1 columns]
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# LWB
# 2024/Q3(wrz24)
# 0.41
# RDS
# 2024/Q3(wrz24)
# 0.43
# ENT
# 2024/Q3(wrz24)
# 0.51
# LBW
# 2024/Q3(wrz24)
# 0.54
# MEG
# 2024/Q3(wrz24)
# 0.41
# RGL
# 2024/Q3(wrz24)
# 0.54
# NOV
# 2024/Q3(wrz24)
# 0.45
# OVI
# 2024/Q3(wrz24)
# 0.54
# PRH
# 2024/Q3(wrz24)
# 0.43
# TGS
# 2024/Q3(wrz24)
# 0.42
# K2P
# 2024/Q3(wrz24)
# 0.41
# ATJ
# 2024/Q3(wrz24)
# 0.4
#     symbol okresAktualny_spadek_CENA_Bilans  \
# 0
# PCO    PCO                              AKT
# GOV    GOV                              AKT
# MGT    MGT                              AKT
# ACG    ACG                              AKT
# ATS    ATS                              AKT
# ..     ...                              ...
# CRM    CRM                              AKT
# CSR    CSR                              AKT
# MOC    MOC                              AKT
# PRI    PRI                              AKT
# ICE    ICE                              AKT
#
#      AktualnyKwartal_Spadek_CENA_Bilans   Kurs  cena akt  okresPoprzedni  \
# 0
# PCO                                0.43  51.00    15.420             NaN
# GOV                                0.26   0.29     0.270             NaN
# MGT                                0.19  79.80    70.000  2024/Q3(wrz24)
# ACG                                0.20  27.50    32.600  2024/Q3(wrz24)
# ATS                                0.34   2.64     0.090             NaN
# ..                                  ...    ...       ...             ...
# CRM                                0.22   0.38     0.516  2024/Q3(wrz24)
# CSR                                0.34   7.90     5.450  2024/Q3(wrz24)
# MOC                                0.21  10.10     9.100  2024/Q3(wrz24)
# PRI                                0.28   3.76     3.800  2024/Q3(wrz24)
# ICE                                0.22   7.80     8.420  2024/Q3(wrz24)
#
#      poprzedniKwartalSpadek_bilans   okresAktualny  \
# 0
# PCO                            NaN             NaN
# GOV                            NaN             NaN
# MGT                           0.20             NaN
# ACG                           0.15             NaN
# ATS                            NaN             NaN
# ..                             ...             ...
# CRM                           0.20  2024/Q4(gru24)
# CSR                           0.25  2024/Q4(gru24)
# MOC                           0.32  2024/Q4(gru24)
# PRI                           0.20  2024/Q4(gru24)
# ICE                           0.27  2024/Q4(gru24)
#
#      AktualnyKwartalSpadek_bilans okresAktualnyCENA_Bilans  \
# 0
# PCO                           NaN                      AKT
# GOV                           NaN                      AKT
# MGT                           NaN                      AKT
# ACG                           NaN                      AKT
# ATS                           NaN                      AKT
# ..                            ...                      ...
# CRM                          0.22                      AKT
# CSR                          0.32                      AKT
# MOC                          0.16                      AKT
# PRI                          0.26                      AKT
# ICE                          0.16                      AKT
#
#      AktualnyKwartalWzrostCENA_Bilans okresPoprzedniBilans  \
# 0
# PCO                              0.32                  NaN
# GOV                              0.26                  NaN
# MGT                              0.10       2024/Q3(wrz24)
# ACG                              0.11       2024/Q3(wrz24)
# ATS                              0.60                  NaN
# ..                                ...                  ...
# CRM                              0.16       2024/Q3(wrz24)
# CSR                              0.25       2024/Q3(wrz24)
# MOC                              0.25       2024/Q3(wrz24)
# PRI                              0.18       2024/Q3(wrz24)
# ICE                              0.28       2024/Q3(wrz24)
#
#      poprzedniKwartalWzrostBilans okresAktualnyBilans  \
# 0
# PCO                           NaN                 NaN
# GOV                           NaN                 NaN
# MGT                          0.03                 NaN
# ACG                          0.08                 NaN
# ATS                           NaN                 NaN
# ..                            ...                 ...
# CRM                          0.12      2024/Q4(gru24)
# CSR                          0.12      2024/Q4(gru24)
# MOC                          0.09      2024/Q4(gru24)
# PRI                          0.07      2024/Q4(gru24)
# ICE                          0.02      2024/Q4(gru24)
#
#      AktualnyKwartalWzrostBilans
# 0
# PCO                          NaN
# GOV                          NaN
# MGT                          NaN
# ACG                          NaN
# ATS                          NaN
# ..                           ...
# CRM                         0.10
# CSR                         0.11
# MOC                         0.39
# PRI                         0.16
# ICE                         0.30
#
# [763 rows x 15 columns]
# 802
# 1206
# procent + 20%
# 66.50082918739635
# procent + 5%
# 75.787728026534
# procent <> -10%
# 12.354892205638475
# procent + 20% w test
# 11.820191599115697

# %%
import pandas as pd
dfFinal=pd.read_excel('/content/drive/MyDrive/raportSpadekBilans.xlsx')
dfFinal22=pd.read_excel('/content/drive/MyDrive/raportSpadek.xlsx')
dfFFbilans=dfFinal[['symbol','okresPoprzedni','poprzedniKwartalSpadek_bilans','poprzedniKwartalWzrostBilans','okresAktualny','AktualnyKwartalSpadek_bilans','AktualnyKwartalWzrostBilans','okresAktualnyCENA_Bilans','AktualnyKwartal_Spadek_CENA_Bilans','AktualnyKwartalWzrostCENA_Bilans','Kurs','cena akt']]
print(dfFinal22.columns)
dfFF=dfFinal22[['symbol','okresPoprzedni','poprzedniKwartalSpadek','poprzedniKwartalWzrost','okresAktualny','AktualnyKwartalSpadek','AktualnyKwartalWzrost','okresAktualnyCENA','AktualnyKwartalSpadekCENA','AktualnyKwartalWzrostCENA']]

dfFFbilans=dfFFbilans.set_index('symbol',drop=False)

dfFF=dfFF.set_index('symbol',drop=False)
dfFFbilans['roznicaBilans']=dfFFbilans['AktualnyKwartalWzrostBilans']-dfFFbilans['AktualnyKwartalSpadek_bilans']
dfFF['roznica']=dfFF['AktualnyKwartalWzrost']-dfFF['AktualnyKwartalSpadek']
ingotwanie_symbol=['OEX','REM','LHD','PGG','SES','OVO']
#ingotwanie_symbol=[]
dfFFbilans['roznica']=dfFFbilans.apply(lambda x: dfFF.loc[x['symbol'],'roznica'] if x['symbol'] not in ingotwanie_symbol  else x['roznicaBilans'],axis=1)

dfFFbilans['srednia']=dfFFbilans.apply(lambda x: (x['roznicaBilans']+x['roznica'])/2 if x['roznicaBilans'] != None and x['roznica'] != None else None,axis=1)
dfFFbilans['docelowaCenatemp'] = np.where(dfFFbilans['srednia'] < 0,dfFFbilans['srednia']*10,(dfFFbilans['srednia']-dfFFbilans['AktualnyKwartalSpadek_bilans'])*10)
dfFFbilans['docelowaCenatemp'] = dfFFbilans['docelowaCenatemp']*0.2
dfFFbilans['Cena docelowa']=dfFFbilans['Kurs']+(dfFFbilans['Kurs']*dfFFbilans['docelowaCenatemp'])
dfFFbilans['potencjalny wzrost']=(dfFFbilans['Cena docelowa']-dfFFbilans['cena akt'])/dfFFbilans['cena akt']
# dfFFbilans['potencjalny wzrost']=dfFFbilans['potencjalny wzrost']*100
print(dfFFbilans)


dfFFbilans.to_excel('/content/drive/MyDrive/raportSpadekBilans_FINAL.xlsx')
dfFF.to_excel('/content/drive/MyDrive/raportSpadek.xlsx')
# Out:
# Index(['symbol', 'symbol.1', 'okresPoprzedni', 'poprzedniKwartalSpadek',
#        'poprzedniKwartalWzrost', 'okresAktualny', 'AktualnyKwartalSpadek',
#        'AktualnyKwartalWzrost', 'okresAktualnyCENA',
#        'AktualnyKwartalSpadekCENA', 'AktualnyKwartalWzrostCENA', 'roznica'],
#       dtype='object')
#        symbol  okresPoprzedni  poprzedniKwartalSpadek_bilans  \
# symbol
# PCO       PCO             NaN                            NaN
# GOV       GOV             NaN                            NaN
# MGT       MGT  2024/Q3(wrz24)                           0.20
# ACG       ACG  2024/Q3(wrz24)                           0.15
# ATS       ATS             NaN                            NaN
# ...       ...             ...                            ...
# CRM       CRM  2024/Q3(wrz24)                           0.20
# CSR       CSR  2024/Q3(wrz24)                           0.25
# MOC       MOC  2024/Q3(wrz24)                           0.32
# PRI       PRI  2024/Q3(wrz24)                           0.20
# ICE       ICE  2024/Q3(wrz24)                           0.27
#
#         poprzedniKwartalWzrostBilans   okresAktualny  \
# symbol
# PCO                              NaN             NaN
# GOV                              NaN             NaN
# MGT                             0.03             NaN
# ACG                             0.08             NaN
# ATS                              NaN             NaN
# ...                              ...             ...
# CRM                             0.12  2024/Q4(gru24)
# CSR                             0.12  2024/Q4(gru24)
# MOC                             0.09  2024/Q4(gru24)
# PRI                             0.07  2024/Q4(gru24)
# ICE                             0.02  2024/Q4(gru24)
#
#         AktualnyKwartalSpadek_bilans  AktualnyKwartalWzrostBilans  \
# symbol
# PCO                              NaN                          NaN
# GOV                              NaN                          NaN
# MGT                              NaN                          NaN
# ACG                              NaN                          NaN
# ATS                              NaN                          NaN
# ...                              ...                          ...
# CRM                             0.22                         0.10
# CSR                             0.32                         0.11
# MOC                             0.16                         0.39
# PRI                             0.26                         0.16
# ICE                             0.16                         0.30
#
#        okresAktualnyCENA_Bilans  AktualnyKwartal_Spadek_CENA_Bilans  \
# symbol
# PCO                         AKT                                0.43
# GOV                         AKT                                0.26
# MGT                         AKT                                0.19
# ACG                         AKT                                0.20
# ATS                         AKT                                0.34
# ...                         ...                                 ...
# CRM                         AKT                                0.22
# CSR                         AKT                                0.34
# MOC                         AKT                                0.21
# PRI                         AKT                                0.28
# ICE                         AKT                                0.22
#
#         AktualnyKwartalWzrostCENA_Bilans   Kurs  cena akt  roznicaBilans  \
# symbol
# PCO                                 0.32  51.00    15.420            NaN
# GOV                                 0.26   0.29     0.270            NaN
# MGT                                 0.10  79.80    70.000            NaN
# ACG                                 0.11  27.50    32.600            NaN
# ATS                                 0.60   2.64     0.090            NaN
# ...                                  ...    ...       ...            ...
# CRM                                 0.16   0.38     0.516          -0.12
# CSR                                 0.25   7.90     5.450          -0.21
# MOC                                 0.25  10.10     9.100           0.23
# PRI                                 0.18   3.76     3.800          -0.10
# ICE                                 0.28   7.80     8.420           0.14
#
#         roznica  srednia  docelowaCenatemp  Cena docelowa  potencjalny wzrost
# symbol
# PCO         NaN      NaN               NaN            NaN                 NaN
# GOV         NaN      NaN               NaN            NaN                 NaN
# MGT         NaN      NaN               NaN            NaN                 NaN
# ACG         NaN      NaN               NaN            NaN                 NaN
# ATS         NaN      NaN               NaN            NaN                 NaN
# ...         ...      ...               ...            ...                 ...
# CRM       -0.22   -0.170             -0.34         0.2508           -0.513953
# CSR       -0.23   -0.220             -0.44         4.4240           -0.188257
# MOC       -0.07    0.080             -0.16         8.4840           -0.067692
# PRI        0.02   -0.040             -0.08         3.4592           -0.089684
# ICE        0.13    0.135             -0.05         7.4100           -0.119952
#
# [763 rows x 18 columns]
